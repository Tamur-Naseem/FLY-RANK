# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamur-Naseem/FLY-RANK/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tamur-Naseem/FLY-RANK/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
**Lane:** Lane 2 — Refresh / Content Opportunity Scoring.

**Why:** I want to build a ranked queue that identifies which pages should be reviewed first for an update. Building a robust scoring system with clear reason codes is a highly practical way to process and prioritize a large dataset, moving beyond the limitations of rigid, hand-written rules.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
*   **The Decision:** Which specific pages out of thousands should the content team prioritize for a refresh?
*   **The Action:** An SEO manager or editor investigates the top-ranked pages to improve content depth, update stale information, or fix metadata.
*   **The Cost of a Wrong Call:** Wasting human review capacity on low-value pages or pages experiencing normal seasonal drops, while missing high-value pages that are silently losing ground.
*   **Why ML helps:** A simple baseline rule treats all features rigidly. ML can weigh multiple competing signals (e.g., high impressions but dropping CTR combined with content age) to score and rank opportunities much more accurately.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd

# 1. Download your repository into Colab if it isn't there already
if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    # !git clone https://github.com/Tamur-Naseem/FLY-RANK.git
    os.chdir("FLY-RANK")

# 2. Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 3. Calculate the baseline metrics
total_pages = len(df)
declining_pages = len(df[df["trend_direction"] == "down"])
decline_rate = declining_pages / total_pages * 100

print(f"Total pages in starter sample: {total_pages:,}")
print(f"Pages currently flagged as declining: {declining_pages:,} ({decline_rate:.1f}%)")
print("\nWhy this matters: With over 14,000 pages showing downward trends,")
print("a human team cannot review them all. We must build a ranked queue to surface the most urgent pages first.")
# Out:
# Cloning into 'FLY-RANK'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 35), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 4.42 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Total pages in starter sample: 30,000
# Pages currently flagged as declining: 16,262 (54.2%)
#
# Why this matters: With over 14,000 pages showing downward trends,
# a human team cannot review them all. We must build a ranked queue to surface the most urgent pages first.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
This project outputs a ranked queue for decision-support. It helps human reviewers prioritize their time.

It relies purely on observational data. I will not claim that a high score guarantees a page is broken, nor will I claim that a refresh will definitively cause a recovery, as this data cannot prove causality.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
